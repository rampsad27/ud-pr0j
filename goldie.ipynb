# %% [markdown]
# <a href="https://colab.research.google.com/github/rampsad27/ud-pr0j/blob/main/goldie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("data.csv",index_col="date",parse_dates=True)

# %%
data.head()
# Out:
#             price
# date
# 1950-01-01  34.73
# 1950-02-01  34.73
# 1950-03-01  34.73
# 1950-04-01  34.73
# 1950-05-01  34.73

# %%
import matplotlib.pyplot as plt

# %%
data.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='date'>

# %%
data.index.freq= "MS"
data.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='date'>

# %%
datayearly = data.rolling(window=12).mean()

# %%
datayearly.plot()
# Out:
# <Axes: xlabel='date'>
